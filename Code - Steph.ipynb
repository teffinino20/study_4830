# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
darwin_data = pd.read_csv("data.csv")
darwin_data.head()
# Out:
#      ID  air_time1  disp_index1  gmrt_in_air1  gmrt_on_paper1  \
# 0  id_1       5160     0.000013    120.804174       86.853334
# 1  id_2      51980     0.000016    115.318238       83.448681
# 2  id_3       2600     0.000010    229.933997      172.761858
# 3  id_4       2130     0.000010    369.403342      183.193104
# 4  id_5       2310     0.000007    257.997131      111.275889
#
#    max_x_extension1  max_y_extension1  mean_acc_in_air1  mean_acc_on_paper1  \
# 0               957              6601          0.361800            0.217459
# 1              1694              6998          0.272513            0.144880
# 2              2333              5802          0.387020            0.181342
# 3              1756              8159          0.556879            0.164502
# 4               987              4732          0.266077            0.145104
#
#    mean_gmrt1  ...  mean_jerk_in_air25  mean_jerk_on_paper25  \
# 0  103.828754  ...            0.141434              0.024471
# ...

# %%
X = darwin_data.drop(['ID', 'class'], axis=1)
y = darwin_data['class']

# %%
tasks = list(range(1, 26))  # Task numbers from 1 to 25
features = [
    'air_time', 'disp_index', 'gmrt_in_air', 'gmrt_on_paper', 'max_x_extension',
    'max_y_extension', 'mean_acc_in_air', 'mean_acc_on_paper', 'mean_gmrt', 
    'mean_jerk_in_air', 'mean_jerk_on_paper', 'mean_speed_in_air', 
    'mean_speed_on_paper', 'num_of_pendown', 'paper_time', 'pressure_mean', 
    'pressure_var', 'total_time'
]

X2 = pd.DataFrame(index=X.index)

for i in tasks:
    task_features = [f'{feature}{i}' for feature in features]
    X2[f'Task{i}'] = X[task_features].values.tolist()


print(X2.head())
# Out:
#                                                Task1  \
# 0  [5160.0, 1.25e-05, 120.8041741, 86.85333376, 9...
# 1  [51980.0, 1.6e-05, 115.3182382, 83.44868072, 1...
# 2  [2600.0, 1.03e-05, 229.9339973, 172.7618583, 2...
# 3  [2130.0, 1.03e-05, 369.4033417, 183.1931039, 1...
# 4  [2310.0, 6.86e-06, 257.997131, 111.275889, 987...
#
#                                                Task2  \
# 0  [6085.0, 1.19e-05, 269.3557887, 51.34226273, 7...
# 1  [10515.0, 1.51e-05, 272.7712368, 73.11585467, ...
# 2  [560.0, 1.05e-05, 122.8095843, 92.98327881, 32...
# 3  [13735.0, 1.4e-05, 185.2785059, 50.14155473, 6...
# 4  [4225.0, 1.2e-05, 112.6196852, 63.49016434, 28...
#
#                                                Task3  \
# 0  [4345.0, 1.33e-05, 330.4875726, 106.6112291, 4...
# 1  [15885.0, 1.25e-05, 240.3823718, 107.6481797, ...
# 2  [420.0, 8.63e-06, 82.56239194, 146.1162954, 46...
# 3  [3795.0, 1.39e-05, 323.2731943, 75.71159615, 4...
# ...

# %%
X2.shape
# Out:
# (174, 25)
